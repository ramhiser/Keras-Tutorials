# %%
import numpy as np
import keras
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Loads the training and test data sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
num_classes = len(np.unique(y_train))
num_classes
# Out:
# 10

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
input_dim = np.prod(X_train.shape[1:])
input_dim
# Out:
# 784

# %%
# The training and test data sets are integers, ranging from 0 to 255.
# We reshape the training and test data sets to be matrices with 784 (= 28 * 28) features.
X_train = X_train.reshape(60000, input_dim).astype('float32')
X_test = X_test.reshape(10000, input_dim).astype('float32')

# %%
# Scales the training and test data to range between 0 and 1.
max_value = X_train.max()
X_train /= max_value
X_test /= max_value

# %%
# The trainign and test labels are integers from 0 to 9 indicating the class label
(y_train, y_test)
# Out:
# (array([5, 0, 4, ..., 5, 6, 8], dtype=uint8),
#  array([7, 2, 1, ..., 4, 5, 6], dtype=uint8))

# %%
# We convert the class labels to binary class matrices
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# %%
# All the logic to build a (multinomial) logistic regression classifier
model = Sequential()
model.add(Dense(num_classes, input_dim=input_dim, activation='softmax'))

# %%
# Summary of model
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_1 (Dense)                  (None, 10)            7850        dense_input_1[0][0]
# ====================================================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
# Trains the model, iterating on the training data in batches of 32 in 10 epochs.
# The optimizer is stochastic gradient descent (SGD).
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, nb_epoch=10, verbose=1)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 1s - loss: 0.7755 - acc: 0.8201
# Epoch 2/10
# 60000/60000 [==============================] - 1s - loss: 0.4564 - acc: 0.8811
# Epoch 3/10
# 60000/60000 [==============================] - 1s - loss: 0.4036 - acc: 0.8921
# Epoch 4/10
# 60000/60000 [==============================] - 2s - loss: 0.3771 - acc: 0.8968
# Epoch 5/10
# 60000/60000 [==============================] - 2s - loss: 0.3603 - acc: 0.9000
# Epoch 6/10
# 60000/60000 [==============================] - 2s - loss: 0.3484 - acc: 0.9030
# Epoch 7/10
# 60000/60000 [==============================] - 2s - loss: 0.3394 - acc: 0.9056
# Epoch 8/10
# 60000/60000 [==============================] - 2s - loss: 0.3323 - acc: 0.9072
# Epoch 9/10
# 60000/60000 [==============================] - 2s - loss: 0.3264 - acc: 0.9090
# Epoch 10/10
# 60000/60000 [==============================] - 2s - loss: 0.3214 - acc: 0.9106

# %%
# Test accuracy is ~92%.
model.evaluate(X_test, y_test, verbose=False)
# Out:
# [0.30678295497894287, 0.91710000000000003]
